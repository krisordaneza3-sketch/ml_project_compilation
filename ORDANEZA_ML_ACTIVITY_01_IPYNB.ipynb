# %% [markdown]
# <a href="https://colab.research.google.com/github/krisordaneza3-sketch/ml_project_compilation/blob/main/ORDANEZA_ML_ACTIVITY_01_IPYNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df['species'] = iris.target_names[iris.target]

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print ("number of observation:", df.shape [0])
print ("number of features:", df.shape[1]-1)
# Out:
# number of observation: 150
# number of features: 4

# %%
df.info()

# %%
df.describe()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df["species"] = iris.target_names[iris.target]

plt.figure(figsize=(8, 9))

plt.scatter(
    df["sepal length (cm)"],
    df["sepal width (cm)"]
)

plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.title("Sepal Length vs Sepal Width")

plt.show()

# %%
plt.figure(figsize=(8, 6))

for species in df["species"].unique():
    subset = df[df["species"] == species]

    plt.scatter(
        subset["petal length (cm)"],
        subset["petal width (cm)"],
        label=species
    )

plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")
plt.legend()

plt.show()

# %%
x=iris.data
y=iris.target

# %%
print("x shape:", x.shape)
print("y shape:", y.shape)
# Out:
# x shape: (150, 4)
# y shape: (150,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit (x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = model.predict(x_test)

# %%
print("Actual:")
print(np.asarray(y_test))

print("\nPredicted:")
print(np.asarray(y_pred))
# Out:
# Actual:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
#
# Predicted:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
new_flower= [[5.1, 3.5, 1.4, 0.2]]

# %%
prediction = model.predict(new_flower)
print(
    "Predicted Species:",
    iris.target_names [prediction]
)
# Out:
# Predicted Species: ['setosa']
